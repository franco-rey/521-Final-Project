# %% [markdown]
# # Machine Learning 521 Final Report
# ## Predicting Quarterly Earnings per Share with Time Series Data
# #### RNN by Franco Rey
# #### Gradient Boosted Regressor Trees by Hank Beck
# #### Random Forest Regression by Bhavesh
# #### Kmean Regime Clustering and Markov Chain by Kevin

# %% [markdown]
# # Introduction
#     - What is the problem?
#     - What are traditional methods for forecasting returns?
#     - What is the benefit of machine learning to this problem
#     - What models did we choose to explore

# %% [markdown]
# # Data
#
# ## Target
#     - Reported EPS
#
# ## Features
#
# ## Data Sources
#     - Yahoo finance
#     - Alpha Vantage
#
# ## Things that needed to be accounted for
#     - look ahead bias
#     - Information available when predictions are to be made
#     - Stationarity
#     - survivorship Bias
#
# ## Pros of the data set
#
# ## Cons of dataset
#
# ## Ways the dataset could be theorectically improved if more data available
#     - longer time period

# %% [markdown]
# # Data Fetching and Cleaning
# I will work here before merging with main so we have a backup in case someone messes up a merge with their independent branch

# %%
# import modules
import pandas as pd
import pandas_datareader as pdr
import requests
import os
from dotenv import load_dotenv
import csv
import numpy as np

# Modules for fetching data
import yfinance as yf

# %%
load_dotenv()
AV_api_key = os.getenv("ALPHA_VANTAGE_API_KEY")

# %% [markdown]
# ## Helper functions

# %% [markdown]
# ### Data retrieval and cleanup helper functions

# %%
def DeleteEmptyCSVs(CSVToCheck):
    # Function to delete any csvs that were created by an attempted data retrieval
    # but are empty of data
    if os.path.isfile(CSVToCheck):
        # Count the number of lines in the file
        with open(CSVToCheck, 'r') as file:
            reader = csv.reader(file)
            line_count = sum(1 for row in reader)
        
        print(f"The file {CSVToCheck} has {line_count} lines.")

        # Check if the line count is less 3 (header and empty line)
        if line_count < 3:
            print(f"{CSVToCheck} seems empty. Deleting the file.")
            os.remove(CSVToCheck)
        else:
            print(f"{CSVToCheck} seems to have data.")
    else:
        print(f"{CSVToCheck} does not exist.")

# %%
def getYahoo(tckr, tckr_csv):
    
    if not os.path.isfile(tckr_csv):
        print("Retrieving "+tckr+" Data from Yahoo...")
        try:
            tckr_data = yf.download(tckr, start=START_DATE_yahoo, end=END_DATE_yahoo)
            print("saving data to csv")
            tckr_data.to_csv(tckr_csv)
        except Exception as e:
            print(f"Failed to retrieve data: {e}")
    else:
        print(tckr+" data already saved in csv")

# %%
def getDividends(tckr):
    ticker = yf.Ticker(tckr)
    dividends_series = ticker.dividends
    csvFile = '.\data_files\\'
    csvFile = csvFile + tckr + 'dividends.csv'
    dividends_series.to_csv(csvFile)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3002929340.py:4: SyntaxWarning: invalid escape sequence '\d'
#   csvFile = '.\data_files\\'

# %%
def GetEarningsFromAlphaVantage(stock_ticker, data_folder = 'data_files'):
    # Request from API
    url = f'https://www.alphavantage.co/query?function=EARNINGS&symbol={stock_ticker}&apikey={AV_api_key}'
    response = requests.get(url)
    data = response.json()
    quarterly_file =  stock_ticker + 'quarterlyEarnings.csv'
    #annual_file =  stock_ticker + 'annualEarnings.csv'
    quarterly_csv = os.path.join(data_folder, quarterly_file)
    #annual_csv = os.path.join(data_folder, annual_file)
    # Parse the response to get EPS data and save it as a CSV file
    quarterly_earnings = data['quarterlyEarnings']
    #annual_earnings = data['annualEarnings']
    if not os.path.isfile(quarterly_csv):
        with open(quarterly_csv, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Fiscal Date','Estimated EPS', 'Reported EPS'])  # Write header row
            for earnings_data in quarterly_earnings:
                fiscal_date = earnings_data['fiscalDateEnding']
                estimated_eps = earnings_data['estimatedEPS']
                reported_eps = earnings_data['reportedEPS']
                writer.writerow([fiscal_date, estimated_eps, reported_eps])
    else:
        print("Quarterly Earnings CSV already present")
    # Report save
        
    print(f" Quarterly Earnings data saved to {quarterly_csv}")

# %%
def BalanceSheetFromAlphaVantage(stock_ticker, data_folder = 'data_files'):
    # Request from API
    url = 'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=IBM&apikey=demo'
    response = requests.get(url)
    data = response.json()
    quarterly_file =  stock_ticker + 'quarterlyBalSheet.csv'
    #annual_file =  stock_ticker + 'annualEarnings.csv'
    quarterly_csv = os.path.join(data_folder, quarterly_file)
    #annual_csv = os.path.join(data_folder, annual_file)
    # Parse the response to get EPS data and save it as a CSV file
    quarterly_reports = data['quarterlyReports']
    #annual_earnings = data['annualEarnings']
    if not os.path.isfile(quarterly_csv):
        with open(quarterly_csv, mode='w', newline='') as file:
            writer = csv.writer(file)
            balance_sheet_items = list(quarterly_reports[0].keys())
            writer.writerow(balance_sheet_items)  # Write header row
            for report in quarterly_reports:
                curr_row = []
                for item in balance_sheet_items:
                    curr_row.append(report[item])
                writer.writerow(curr_row)
    else:
        print("Quarterly Earnings CSV already present")
    # Report save
        
    print(f" Quarterly Earnings data saved to {quarterly_csv}")

# %% [markdown]
# ## Fetching Initial Data

# %% [markdown]
# ### Sourced from yahoo

# %%
START_DATE_yahoo ="1990-01-01"
END_DATE_yahoo = "2024-05-30"

# Larger Market trends 

# S&P 500
sp500_ticker = '^GSPC'
sp500_csv = '.\data_files\sp500_RawData.csv'
START_DATE_sp500 = START_DATE_yahoo
END_DATE_sp500 = END_DATE_yahoo

# CBOE Volatility Index (VIX)
vix_ticker = '^VIX'
vix_csv = '.\data_files\VIX_RawData.csv'
START_DATE_vix = START_DATE_yahoo
END_DATE_vix = END_DATE_yahoo

# Large Cap Stocks

# Microsoft (MSFT)
micro_ticker = 'MSFT'
micro_csv = '.\data_files\MSFT_RawData.csv'
micro_earnings_csv = '.\data_files\MSFTquarterlyEarnings.csv'
micro_balSht_csv = '.\data_files\MSFTquarterlyBalSheet.csv'
START_DATE_msft = START_DATE_yahoo
END_DATE_msft = END_DATE_yahoo

# General Electric (GE)
general_elec_ticker = 'GE'
ge_csv = '.\data_files\GE_RawData.csv'
START_DATE_ge = START_DATE_yahoo
END_DATE_ge = END_DATE_yahoo

# Johnson and Johnson (JNJ)
jj_ticker = 'JNJ'
jj_csv = '.\data_files\JNJ_RawData.csv'
jj_earnings_csv = '.\data_files\JNJquarterlyEarnings.csv'
jj_balSht_csv = '.\data_files\JNJquarterlyBalSheet.csv'
jj_dividend_csv = '.\data_files\JNJdividends.csv'
START_DATE_jj = START_DATE_yahoo
END_DATE_jj = END_DATE_yahoo

# Coca Cola (KO)
cc_ticker = 'KO'
cc_csv = '.\data_files\KO_RawData.csv'
START_DATE_cc = START_DATE_yahoo
END_DATE_cc = END_DATE_yahoo
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# <>:23: SyntaxWarning: invalid escape sequence '\d'
# <>:24: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# <>:36: SyntaxWarning: invalid escape sequence '\d'
# <>:37: SyntaxWarning: invalid escape sequence '\d'
# <>:38: SyntaxWarning: invalid escape sequence '\d'
# <>:39: SyntaxWarning: invalid escape sequence '\d'
# <>:45: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# <>:23: SyntaxWarning: invalid escape sequence '\d'
# <>:24: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# <>:36: SyntaxWarning: invalid escape sequence '\d'
# <>:37: SyntaxWarning: invalid escape sequence '\d'
# <>:38: SyntaxWarning: invalid escape sequence '\d'
# <>:39: SyntaxWarning: invalid escape sequence '\d'
# <>:45: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:8: SyntaxWarning: invalid escape sequence '\d'
#   sp500_csv = '.\data_files\sp500_RawData.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:14: SyntaxWarning: invalid escape sequence '\d'
#   vix_csv = '.\data_files\VIX_RawData.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:22: SyntaxWarning: invalid escape sequence '\d'
#   micro_csv = '.\data_files\MSFT_RawData.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:23: SyntaxWarning: invalid escape sequence '\d'
#   micro_earnings_csv = '.\data_files\MSFTquarterlyEarnings.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:24: SyntaxWarning: invalid escape sequence '\d'
#   micro_balSht_csv = '.\data_files\MSFTquarterlyBalSheet.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:30: SyntaxWarning: invalid escape sequence '\d'
#   ge_csv = '.\data_files\GE_RawData.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:36: SyntaxWarning: invalid escape sequence '\d'
#   jj_csv = '.\data_files\JNJ_RawData.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:37: SyntaxWarning: invalid escape sequence '\d'
#   jj_earnings_csv = '.\data_files\JNJquarterlyEarnings.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:38: SyntaxWarning: invalid escape sequence '\d'
#   jj_balSht_csv = '.\data_files\JNJquarterlyBalSheet.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:39: SyntaxWarning: invalid escape sequence '\d'
#   jj_dividend_csv = '.\data_files\JNJdividends.csv'
# C:\Users\kzhan\AppData\Local\Temp\ipykernel_11324\3571019094.py:45: SyntaxWarning: invalid escape sequence '\d'
#   cc_csv = '.\data_files\KO_RawData.csv'

# %% [markdown]
# ## S&P 500 (representative of of larger market trends)

# %%
#getYahoo(sp500_ticker, sp500_csv)

# %% [markdown]
# ## VIX (overall market volatility)

# %%
#getYahoo(vix_ticker,vix_csv)

# %% [markdown]
# ## Johnson and Johnson Historical Stock Price

# %%
#getYahoo(jj_ticker, jj_csv)

# %% [markdown]
# ## Microsoft Historical Stock Price

# %%
#getYahoo(micro_ticker,micro_csv)

# %% [markdown]
# ## Dividend data

# %%
#getDividends(jj_ticker)

# %%
#getDividends(micro_ticker)

# %% [markdown]
# # Alpha Vantage Accounting Data

# %%
#BalanceSheetFromAlphaVantage(stock_ticker=micro_ticker)
#GetEarningsFromAlphaVantage(stock_ticker= micro_ticker)

# %%
#BalanceSheetFromAlphaVantage(stock_ticker=jj_ticker)
#GetEarningsFromAlphaVantage(stock_ticker= jj_ticker)

# %% [markdown]
# # FROM CSVs Create Collated Data Frame
#
# Features to Extract:
#
#     - reported Earnings Per Share
#     - Total Assets
#     - Accruals
#     - Equity Ratio
#     - Cash Dividends Paid Since last Quarter
#     - VIX Lagged By By several steps out
#         - Can achieve some granularity this way despite looking to make quarterly predictions for earnings
#     - S&P Lagged for several steps
#         - Can provide information on how it has moved over the last several weeks not just quarter to quarter snapshots

# %%
Market_Features_to_drop = ['Volume','High','Low','Adj Close']
Balance_sheet_features_to_keep = ['totalAssets','totalShareholderEquity']

# Get Price Data
SP500_raw_df = pd.read_csv(sp500_csv, index_col = 'Date')
VIX_raw_df = pd.read_csv(vix_csv, index_col = 'Date')
JJ_raw_price_df = pd.read_csv(jj_csv, index_col = 'Date')

# Get Quarterly Data
JJ_Earnings_df = pd.read_csv(jj_earnings_csv)
JJ_Earnings_df['Date'] = pd.to_datetime(JJ_Earnings_df['Fiscal Date'])
JJ_Earnings_df.drop(columns = ['Fiscal Date'], inplace = True)
JJ_Earnings_df.set_index('Date', inplace = True)
JJ_Earnings_df =  JJ_Earnings_df.iloc[::-1]

JJ_BalSht_df = pd.read_csv(jj_balSht_csv)
JJ_BalSht_df['Date'] = pd.to_datetime(JJ_BalSht_df['fiscalDateEnding'])
JJ_BalSht_df.drop(columns = ['fiscalDateEnding'], inplace = True)
JJ_BalSht_df.set_index('Date', inplace = True)
JJ_BalSht_df =  JJ_BalSht_df.iloc[::-1]

# get Dividend Data
JJ_dividend_df = pd.read_csv(jj_dividend_csv)
JJ_dividend_df['Date'] = JJ_dividend_df['Date'].str.split().str[0]
JJ_dividend_df.set_index('Date', inplace = True)

# drop market feature form S&P and VIX
SP500_raw_df.drop(columns= Market_Features_to_drop, inplace= True)
VIX_raw_df.drop(columns=Market_Features_to_drop, inplace= True)

# drop high and low
JJ_raw_price_df.drop(columns=['High','Adj Close', 'Low'], inplace=True)

# Calculate daily return
SP500_raw_df['Daily_Return_dollars'] = SP500_raw_df['Close'] - SP500_raw_df['Open']
VIX_raw_df['Daily_Return_dollars'] = VIX_raw_df['Close'] - VIX_raw_df['Open']

SP500_raw_df['Daily_Return_percent'] = SP500_raw_df['Daily_Return_dollars']/SP500_raw_df['Open']
VIX_raw_df['Daily_Return_percent'] = VIX_raw_df['Daily_Return_dollars']/VIX_raw_df['Open']

JJ_raw_price_df['Daily_Return_dollars'] = JJ_raw_price_df['Close'] - JJ_raw_price_df['Open']
JJ_raw_price_df['Daily_Return_percent'] = JJ_raw_price_df['Daily_Return_dollars']/JJ_raw_price_df['Open']

# drop open and close
JJ_raw_price_df.drop(columns=['Open','Close','Daily_Return_dollars'], inplace = True)
SP500_raw_df.drop(columns=['Open','Close','Daily_Return_dollars'], inplace = True)
VIX_raw_df.drop(columns=['Open','Close','Daily_Return_dollars'], inplace = True)

# Balance Sheet Features
JJ_Bal_Sheet_reduced_df = JJ_BalSht_df.loc[:,Balance_sheet_features_to_keep]
JJ_Bal_Sheet_reduced_df['Equity Ratio'] = JJ_Bal_Sheet_reduced_df['totalShareholderEquity'] /JJ_Bal_Sheet_reduced_df['totalAssets']
JJ_Bal_Sheet_reduced_df.drop(columns=['totalShareholderEquity'], inplace = True)

# JJ merge
JJ_market_df = JJ_dividend_df.merge(JJ_raw_price_df, left_index=True, right_index=True)
JJ_market_df.index = pd.to_datetime(JJ_market_df.index)
JJ_earnbal_df = JJ_Earnings_df.merge(JJ_Bal_Sheet_reduced_df, left_index = True, right_index = True)
JJ_merge_df = JJ_market_df.merge(JJ_earnbal_df,how = 'outer', left_index= True, right_index= True)

# Merge Raw Data
market_df = SP500_raw_df.merge(VIX_raw_df, left_index=True, right_index=True,suffixes=('_SP','_VIX'))
market_df.index = pd.to_datetime(market_df.index)

merged_df = market_df.merge(JJ_merge_df, how = 'outer', left_index= True, right_index= True)
# Display Data Frame Head
merged_df.head()
# Out:
#             Daily_Return_percent_SP  Daily_Return_percent_VIX  Dividends  \
# Date
# 1990-01-02                 0.017799                       0.0        NaN
# 1990-01-03                -0.002586                       0.0        NaN
# 1990-01-04                -0.008613                       0.0        NaN
# 1990-01-05                -0.009756                       0.0        NaN
# 1990-01-08                 0.004514                       0.0        NaN
#
#             Volume  Daily_Return_percent  Estimated EPS  Reported EPS  \
# Date
# 1990-01-02     NaN                   NaN            NaN           NaN
# 1990-01-03     NaN                   NaN            NaN           NaN
# 1990-01-04     NaN                   NaN            NaN           NaN
# 1990-01-05     NaN                   NaN            NaN           NaN
# 1990-01-08     NaN                   NaN            NaN           NaN
#
#             totalAssets  Equity Ratio
# Date
# 1990-01-02          NaN           NaN
# 1990-01-03          NaN           NaN
# 1990-01-04          NaN           NaN
# 1990-01-05          NaN           NaN
# 1990-01-08          NaN           NaN

# %% [markdown]
# # Summary of the Final Features/ Target and train test split

# %% [markdown]
# # RNN (Franco)
#
# ## Why this model for this problem
#
# * Recurrent nerual networks are specifically designed to handle sequential data, ideal for time-series forecasting. gated neural networks like the LSTM offer nuanced pattern recognition and adapt to macroeconomic trends and cycles over time.

# %% [markdown]
# ## Model Architecture
#
# Our RNN will utilize a Long Short Term Memory Model, as justified by its advantages for time series.

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

batch_size = 64
n_steps = 4
n_features = merged_df.shape[1]

# `merged_df` needs numeric types no missing values
data = merged_df.values

# Normalize features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Forward Fill
merged_df.ffill(inplace=True)

# Backward Fill
merged_df.bfill(inplace=True)

# Fill with Mean (ensure to apply this per feature if your data isn't homogeneous)
merged_df.fillna(merged_df.mean(), inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Apply MinMaxScaler for better normalization
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(merged_df.values)

# Ensure no infinite or NaN values after scaling
data_scaled = np.nan_to_num(data_scaled)

# Ensure no infinite or NaN values after scaling
if np.isinf(data_scaled).any() or np.isnan(data_scaled).any():
    print("Infinite or NaN values found after scaling.")
    data_scaled = np.nan_to_num(data_scaled)  # Replace NaNs and Infs

# %%
# Reshape data to fit the RNN input shape
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(n_steps, len(data)):
        X.append(data[i-n_steps:i, :])
        y.append(data[i, 5])  # Assuming the first column is the target variable
    return np.array(X), np.array(y)

X, y = create_sequences(data_scaled, n_steps)

# Split the dataset
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Model configuration - these need to be adjusted based on your dataset
n_steps = 50  # This should match the number of timesteps you decided to use in your sequences
n_features = merged_df.shape[1]  # Number of features in your dataset

# Define the RNN model
model = Sequential([
    LSTM(50, activation='tanh', input_shape=(n_steps, n_features), return_sequences=True),
    Dropout(0.2),
    LSTM(50, activation='tanh'),
    Dropout(0.2),
    Dense(1)  # Output layer - assumes a single output per sequence
])

# Display model summary to verify its structure
model.summary()
# Out:
# c:\Users\kzhan\Documents\GitHub\521-Final-Project\env\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50, 50)         │        12,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,251 (125.98 KB)
#  Trainable params: 32,251 (125.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model using SGD optimizer
sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=sgd_optimizer, loss='mean_squared_error')

# %%
# Assuming X_train and y_train are already defined and properly shaped
history = model.fit(X_train, y_train, epochs=400, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0023 - val_loss: 0.0489
# Epoch 2/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.6861e-04 - val_loss: 0.0474
# Epoch 3/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.4677e-04 - val_loss: 0.0444
# Epoch 4/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0385e-04 - val_loss: 0.0436
# Epoch 5/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5178e-04 - val_loss: 0.0428
# Epoch 6/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1994e-04 - val_loss: 0.0418
# Epoch 7/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.3063e-04 - val_loss: 0.0403
# Epoch 8/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9225e-04 - val_loss: 0.0401
# Epoch 9/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6424e-04 - val_loss: 0.0400
# Epoch 10/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5321e-04 - val_loss: 0.0394
# Epoch 11/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.7052e-04 - val_loss: 0.0382
# Epoch 12/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0315e-04 - val_loss: 0.0385
# Epoch 13/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.4384e-04 - val_loss: 0.0383
# Epoch 14/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3331e-04 - val_loss: 0.0385
# Epoch 15/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6231e-04 - val_loss: 0.0376
# Epoch 16/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3162e-04 - val_loss: 0.0366
# Epoch 17/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3801e-04 - val_loss: 0.0362
# Epoch 18/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1300e-04 - val_loss: 0.0370
# Epoch 19/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9625e-04 - val_loss: 0.0354
# Epoch 20/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.1198e-04 - val_loss: 0.0353
# Epoch 21/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9530e-04 - val_loss: 0.0351
# Epoch 22/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8786e-04 - val_loss: 0.0350
# Epoch 23/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9452e-04 - val_loss: 0.0345
# Epoch 24/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.0040e-04 - val_loss: 0.0343
# Epoch 25/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2533e-04 - val_loss: 0.0333
# Epoch 26/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8094e-04 - val_loss: 0.0329
# Epoch 27/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9684e-04 - val_loss: 0.0335
# Epoch 28/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9812e-04 - val_loss: 0.0327
# Epoch 29/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7390e-04 - val_loss: 0.0328
# Epoch 30/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7056e-04 - val_loss: 0.0314
# Epoch 31/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4570e-04 - val_loss: 0.0319
# Epoch 32/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4876e-04 - val_loss: 0.0311
# Epoch 33/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5490e-04 - val_loss: 0.0310
# Epoch 34/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7059e-04 - val_loss: 0.0310
# Epoch 35/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5848e-04 - val_loss: 0.0303
# Epoch 36/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.6070e-04 - val_loss: 0.0304
# Epoch 37/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7710e-04 - val_loss: 0.0299
# Epoch 38/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4895e-04 - val_loss: 0.0294
# Epoch 39/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.6860e-04 - val_loss: 0.0292
# Epoch 40/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4473e-04 - val_loss: 0.0283
# Epoch 41/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5151e-04 - val_loss: 0.0284
# Epoch 42/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5438e-04 - val_loss: 0.0282
# Epoch 43/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.2267e-04 - val_loss: 0.0275
# Epoch 44/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.1643e-04 - val_loss: 0.0273
# Epoch 45/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4895e-04 - val_loss: 0.0267
# Epoch 46/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3158e-04 - val_loss: 0.0260
# Epoch 47/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2916e-04 - val_loss: 0.0265
# Epoch 48/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4085e-04 - val_loss: 0.0258
# Epoch 49/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3508e-04 - val_loss: 0.0256
# Epoch 50/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3543e-04 - val_loss: 0.0251
# Epoch 51/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5849e-04 - val_loss: 0.0248
# Epoch 52/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0822e-04 - val_loss: 0.0242
# Epoch 53/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9873e-04 - val_loss: 0.0250
# Epoch 54/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1936e-04 - val_loss: 0.0239
# Epoch 55/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8959e-04 - val_loss: 0.0238
# Epoch 56/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9709e-04 - val_loss: 0.0229
# Epoch 57/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2077e-04 - val_loss: 0.0231
# Epoch 58/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9557e-04 - val_loss: 0.0225
# Epoch 59/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9135e-04 - val_loss: 0.0229
# Epoch 60/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0654e-04 - val_loss: 0.0219
# Epoch 61/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1820e-04 - val_loss: 0.0217
# Epoch 62/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9957e-04 - val_loss: 0.0215
# Epoch 63/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0295e-04 - val_loss: 0.0204
# Epoch 64/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8082e-04 - val_loss: 0.0211
# Epoch 65/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9440e-04 - val_loss: 0.0209
# Epoch 66/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8439e-04 - val_loss: 0.0199
# Epoch 67/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8280e-04 - val_loss: 0.0201
# Epoch 68/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8353e-04 - val_loss: 0.0192
# Epoch 69/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9051e-04 - val_loss: 0.0191
# Epoch 70/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8256e-04 - val_loss: 0.0188
# Epoch 71/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7387e-04 - val_loss: 0.0183
# Epoch 72/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8575e-04 - val_loss: 0.0185
# Epoch 73/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8510e-04 - val_loss: 0.0180
# Epoch 74/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5745e-04 - val_loss: 0.0179
# Epoch 75/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6437e-04 - val_loss: 0.0169
# Epoch 76/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6961e-04 - val_loss: 0.0166
# Epoch 77/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7406e-04 - val_loss: 0.0168
# Epoch 78/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5469e-04 - val_loss: 0.0165
# Epoch 79/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7060e-04 - val_loss: 0.0162
# Epoch 80/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5657e-04 - val_loss: 0.0161
# Epoch 81/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4596e-04 - val_loss: 0.0157
# Epoch 82/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3559e-04 - val_loss: 0.0157
# Epoch 83/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4709e-04 - val_loss: 0.0149
# Epoch 84/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4501e-04 - val_loss: 0.0146
# Epoch 85/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3243e-04 - val_loss: 0.0145
# Epoch 86/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5444e-04 - val_loss: 0.0141
# Epoch 87/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3521e-04 - val_loss: 0.0141
# Epoch 88/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3694e-04 - val_loss: 0.0142
# Epoch 89/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5194e-04 - val_loss: 0.0137
# Epoch 90/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4080e-04 - val_loss: 0.0130
# Epoch 91/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4167e-04 - val_loss: 0.0132
# Epoch 92/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4262e-04 - val_loss: 0.0129
# Epoch 93/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4531e-04 - val_loss: 0.0129
# Epoch 94/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3835e-04 - val_loss: 0.0129
# Epoch 95/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2350e-04 - val_loss: 0.0124
# Epoch 96/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2145e-04 - val_loss: 0.0118
# Epoch 97/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1802e-04 - val_loss: 0.0118
# Epoch 98/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2075e-04 - val_loss: 0.0116
# Epoch 99/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2682e-04 - val_loss: 0.0114
# Epoch 100/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1656e-04 - val_loss: 0.0110
# Epoch 101/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1308e-04 - val_loss: 0.0105
# Epoch 102/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2482e-04 - val_loss: 0.0108
# Epoch 103/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2314e-04 - val_loss: 0.0102
# Epoch 104/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2493e-04 - val_loss: 0.0100
# Epoch 105/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2971e-04 - val_loss: 0.0100
# Epoch 106/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1095e-04 - val_loss: 0.0099
# Epoch 107/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0807e-04 - val_loss: 0.0096
# Epoch 108/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1674e-04 - val_loss: 0.0093
# Epoch 109/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1731e-04 - val_loss: 0.0089
# Epoch 110/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1522e-04 - val_loss: 0.0088
# Epoch 111/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0595e-04 - val_loss: 0.0090
# Epoch 112/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6018e-05 - val_loss: 0.0088
# Epoch 113/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1251e-04 - val_loss: 0.0082
# Epoch 114/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0531e-04 - val_loss: 0.0084
# Epoch 115/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0457e-04 - val_loss: 0.0083
# Epoch 116/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1957e-04 - val_loss: 0.0080
# Epoch 117/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0096e-04 - val_loss: 0.0078
# Epoch 118/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4047e-05 - val_loss: 0.0076
# Epoch 119/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8239e-05 - val_loss: 0.0073
# Epoch 120/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1700e-04 - val_loss: 0.0076
# Epoch 121/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1386e-04 - val_loss: 0.0075
# Epoch 122/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9567e-05 - val_loss: 0.0070
# Epoch 123/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1645e-04 - val_loss: 0.0070
# Epoch 124/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9464e-05 - val_loss: 0.0069
# Epoch 125/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0295e-04 - val_loss: 0.0067
# Epoch 126/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0121e-04 - val_loss: 0.0068
# Epoch 127/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5111e-05 - val_loss: 0.0065
# Epoch 128/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9367e-05 - val_loss: 0.0063
# Epoch 129/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2082e-05 - val_loss: 0.0060
# Epoch 130/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3313e-05 - val_loss: 0.0061
# Epoch 131/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5937e-05 - val_loss: 0.0060
# Epoch 132/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0179e-04 - val_loss: 0.0058
# Epoch 133/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1297e-05 - val_loss: 0.0060
# Epoch 134/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0071e-04 - val_loss: 0.0058
# Epoch 135/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3743e-05 - val_loss: 0.0054
# Epoch 136/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0100e-04 - val_loss: 0.0055
# Epoch 137/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9524e-05 - val_loss: 0.0055
# Epoch 138/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4250e-05 - val_loss: 0.0052
# Epoch 139/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2695e-05 - val_loss: 0.0052
# Epoch 140/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5749e-05 - val_loss: 0.0051
# Epoch 141/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3110e-05 - val_loss: 0.0050
# Epoch 142/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2206e-05 - val_loss: 0.0049
# Epoch 143/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5204e-05 - val_loss: 0.0049
# Epoch 144/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4350e-05 - val_loss: 0.0048
# Epoch 145/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3512e-05 - val_loss: 0.0046
# Epoch 146/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1585e-05 - val_loss: 0.0046
# Epoch 147/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6858e-05 - val_loss: 0.0044
# Epoch 148/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1691e-05 - val_loss: 0.0044
# Epoch 149/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9751e-05 - val_loss: 0.0043
# Epoch 150/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5732e-05 - val_loss: 0.0043
# Epoch 151/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8057e-05 - val_loss: 0.0041
# Epoch 152/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1192e-05 - val_loss: 0.0042
# Epoch 153/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6222e-05 - val_loss: 0.0040
# Epoch 154/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7759e-05 - val_loss: 0.0039
# Epoch 155/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3238e-05 - val_loss: 0.0039
# Epoch 156/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6263e-05 - val_loss: 0.0038
# Epoch 157/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7598e-05 - val_loss: 0.0038
# Epoch 158/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7914e-05 - val_loss: 0.0037
# Epoch 159/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7947e-05 - val_loss: 0.0040
# Epoch 160/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0407e-05 - val_loss: 0.0038
# Epoch 161/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4418e-05 - val_loss: 0.0035
# Epoch 162/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2065e-05 - val_loss: 0.0035
# Epoch 163/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9894e-05 - val_loss: 0.0035
# Epoch 164/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1434e-05 - val_loss: 0.0035
# Epoch 165/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6368e-05 - val_loss: 0.0035
# Epoch 166/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4962e-05 - val_loss: 0.0033
# Epoch 167/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9224e-05 - val_loss: 0.0032
# Epoch 168/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3185e-05 - val_loss: 0.0032
# Epoch 169/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2132e-05 - val_loss: 0.0030
# Epoch 170/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3914e-05 - val_loss: 0.0032
# Epoch 171/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7372e-05 - val_loss: 0.0031
# Epoch 172/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.1979e-05 - val_loss: 0.0028
# Epoch 173/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9777e-05 - val_loss: 0.0030
# Epoch 174/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.0021e-05 - val_loss: 0.0028
# Epoch 175/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6389e-05 - val_loss: 0.0030
# Epoch 176/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7780e-05 - val_loss: 0.0030
# Epoch 177/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5171e-05 - val_loss: 0.0029
# Epoch 178/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.0225e-05 - val_loss: 0.0029
# Epoch 179/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5265e-05 - val_loss: 0.0028
# Epoch 180/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0624e-05 - val_loss: 0.0030
# Epoch 181/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4956e-05 - val_loss: 0.0027
# Epoch 182/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.3865e-05 - val_loss: 0.0028
# Epoch 183/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1574e-05 - val_loss: 0.0028
# Epoch 184/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4166e-05 - val_loss: 0.0027
# Epoch 185/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3263e-05 - val_loss: 0.0026
# Epoch 186/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4470e-05 - val_loss: 0.0027
# Epoch 187/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8715e-05 - val_loss: 0.0026
# Epoch 188/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2225e-05 - val_loss: 0.0026
# Epoch 189/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.5440e-05 - val_loss: 0.0024
# Epoch 190/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.9386e-05 - val_loss: 0.0026
# Epoch 191/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.5098e-05 - val_loss: 0.0025
# Epoch 192/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9844e-05 - val_loss: 0.0024
# Epoch 193/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2498e-05 - val_loss: 0.0024
# Epoch 194/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5806e-05 - val_loss: 0.0023
# Epoch 195/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5546e-05 - val_loss: 0.0023
# Epoch 196/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9967e-05 - val_loss: 0.0023
# Epoch 197/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5102e-05 - val_loss: 0.0023
# Epoch 198/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.3159e-05 - val_loss: 0.0022
# Epoch 199/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.6743e-05 - val_loss: 0.0023
# Epoch 200/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.2931e-05 - val_loss: 0.0023
# Epoch 201/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9243e-05 - val_loss: 0.0022
# Epoch 202/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5409e-05 - val_loss: 0.0023
# Epoch 203/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1082e-05 - val_loss: 0.0024
# Epoch 204/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5060e-05 - val_loss: 0.0021
# Epoch 205/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9452e-05 - val_loss: 0.0021
# Epoch 206/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0160e-05 - val_loss: 0.0022
# Epoch 207/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1755e-05 - val_loss: 0.0021
# Epoch 208/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0309e-05 - val_loss: 0.0021
# Epoch 209/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0580e-05 - val_loss: 0.0021
# Epoch 210/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4049e-05 - val_loss: 0.0020
# Epoch 211/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8982e-05 - val_loss: 0.0020
# Epoch 212/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7395e-05 - val_loss: 0.0021
# Epoch 213/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9304e-05 - val_loss: 0.0019
# Epoch 214/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6793e-05 - val_loss: 0.0019
# Epoch 215/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2188e-05 - val_loss: 0.0019
# Epoch 216/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4723e-05 - val_loss: 0.0020
# Epoch 217/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0663e-05 - val_loss: 0.0019
# Epoch 218/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.1228e-05 - val_loss: 0.0020
# Epoch 219/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0724e-05 - val_loss: 0.0021
# Epoch 220/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8851e-05 - val_loss: 0.0021
# Epoch 221/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9150e-05 - val_loss: 0.0020
# Epoch 222/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2332e-05 - val_loss: 0.0019
# Epoch 223/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2057e-05 - val_loss: 0.0019
# Epoch 224/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0299e-05 - val_loss: 0.0019
# Epoch 225/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1439e-05 - val_loss: 0.0020
# Epoch 226/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5450e-05 - val_loss: 0.0019
# Epoch 227/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3037e-05 - val_loss: 0.0019
# Epoch 228/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9345e-05 - val_loss: 0.0018
# Epoch 229/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1488e-05 - val_loss: 0.0019
# Epoch 230/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1623e-05 - val_loss: 0.0018
# Epoch 231/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3177e-05 - val_loss: 0.0018
# Epoch 232/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.6606e-05 - val_loss: 0.0018
# Epoch 233/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4818e-05 - val_loss: 0.0019
# Epoch 234/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.4460e-05 - val_loss: 0.0018
# Epoch 235/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3100e-05 - val_loss: 0.0018
# Epoch 236/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2757e-05 - val_loss: 0.0018
# Epoch 237/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2796e-05 - val_loss: 0.0018
# Epoch 238/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.6662e-05 - val_loss: 0.0017
# Epoch 239/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.1986e-05 - val_loss: 0.0018
# Epoch 240/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4686e-05 - val_loss: 0.0018
# Epoch 241/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5342e-05 - val_loss: 0.0017
# Epoch 242/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2618e-05 - val_loss: 0.0017
# Epoch 243/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.5321e-05 - val_loss: 0.0017
# Epoch 244/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2631e-05 - val_loss: 0.0017
# Epoch 245/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5960e-05 - val_loss: 0.0017
# Epoch 246/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5234e-05 - val_loss: 0.0017
# Epoch 247/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.6499e-05 - val_loss: 0.0017
# Epoch 248/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.8953e-05 - val_loss: 0.0018
# Epoch 249/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.2965e-05 - val_loss: 0.0018
# Epoch 250/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.9689e-05 - val_loss: 0.0017
# Epoch 251/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4587e-05 - val_loss: 0.0017
# Epoch 252/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9565e-05 - val_loss: 0.0017
# Epoch 253/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8917e-05 - val_loss: 0.0016
# Epoch 254/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9454e-05 - val_loss: 0.0016
# Epoch 255/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3420e-05 - val_loss: 0.0017
# Epoch 256/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8418e-05 - val_loss: 0.0017
# Epoch 257/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3505e-05 - val_loss: 0.0017
# Epoch 258/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4843e-05 - val_loss: 0.0017
# Epoch 259/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9912e-05 - val_loss: 0.0017
# Epoch 260/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4500e-05 - val_loss: 0.0016
# Epoch 261/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5474e-05 - val_loss: 0.0016
# Epoch 262/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6698e-05 - val_loss: 0.0017
# Epoch 263/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5278e-05 - val_loss: 0.0016
# Epoch 264/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9697e-05 - val_loss: 0.0016
# Epoch 265/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3120e-05 - val_loss: 0.0016
# Epoch 266/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4742e-05 - val_loss: 0.0016
# Epoch 267/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9843e-05 - val_loss: 0.0016
# Epoch 268/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7565e-05 - val_loss: 0.0016
# Epoch 269/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4096e-05 - val_loss: 0.0016
# Epoch 270/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2194e-05 - val_loss: 0.0016
# Epoch 271/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2478e-05 - val_loss: 0.0016
# Epoch 272/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3587e-05 - val_loss: 0.0016
# Epoch 273/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1853e-05 - val_loss: 0.0016
# Epoch 274/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.4773e-05 - val_loss: 0.0016
# Epoch 275/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2549e-05 - val_loss: 0.0016
# Epoch 276/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8765e-05 - val_loss: 0.0015
# Epoch 277/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3703e-05 - val_loss: 0.0016
# Epoch 278/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6007e-05 - val_loss: 0.0016
# Epoch 279/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1715e-05 - val_loss: 0.0015
# Epoch 280/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4479e-05 - val_loss: 0.0015
# Epoch 281/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6501e-05 - val_loss: 0.0016
# Epoch 282/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9509e-05 - val_loss: 0.0016
# Epoch 283/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2802e-05 - val_loss: 0.0016
# Epoch 284/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5664e-05 - val_loss: 0.0016
# Epoch 285/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.1966e-05 - val_loss: 0.0015
# Epoch 286/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3980e-05 - val_loss: 0.0015
# Epoch 287/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3990e-05 - val_loss: 0.0015
# Epoch 288/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7704e-05 - val_loss: 0.0015
# Epoch 289/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2223e-05 - val_loss: 0.0014
# Epoch 290/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9075e-05 - val_loss: 0.0015
# Epoch 291/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3187e-05 - val_loss: 0.0015
# Epoch 292/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2888e-05 - val_loss: 0.0015
# Epoch 293/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5327e-05 - val_loss: 0.0015
# Epoch 294/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.7660e-05 - val_loss: 0.0015
# Epoch 295/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2589e-05 - val_loss: 0.0015
# Epoch 296/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8408e-05 - val_loss: 0.0015
# Epoch 297/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1780e-05 - val_loss: 0.0014
# Epoch 298/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4605e-05 - val_loss: 0.0015
# Epoch 299/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5696e-05 - val_loss: 0.0015
# Epoch 300/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3736e-05 - val_loss: 0.0015
# Epoch 301/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9353e-05 - val_loss: 0.0015
# Epoch 302/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5090e-05 - val_loss: 0.0015
# Epoch 303/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0107e-05 - val_loss: 0.0014
# Epoch 304/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5173e-05 - val_loss: 0.0014
# Epoch 305/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8038e-05 - val_loss: 0.0014
# Epoch 306/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0583e-05 - val_loss: 0.0014
# Epoch 307/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8671e-05 - val_loss: 0.0014
# Epoch 308/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.7781e-05 - val_loss: 0.0014
# Epoch 309/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8306e-05 - val_loss: 0.0014
# Epoch 310/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9982e-05 - val_loss: 0.0014
# Epoch 311/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4397e-05 - val_loss: 0.0014
# Epoch 312/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8751e-05 - val_loss: 0.0014
# Epoch 313/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8884e-05 - val_loss: 0.0014
# Epoch 314/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8675e-05 - val_loss: 0.0015
# Epoch 315/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8504e-05 - val_loss: 0.0014
# Epoch 316/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2392e-05 - val_loss: 0.0014
# Epoch 317/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6645e-05 - val_loss: 0.0013
# Epoch 318/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9512e-05 - val_loss: 0.0014
# Epoch 319/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2664e-05 - val_loss: 0.0014
# Epoch 320/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7683e-05 - val_loss: 0.0014
# Epoch 321/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6471e-05 - val_loss: 0.0014
# Epoch 322/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2685e-05 - val_loss: 0.0014
# Epoch 323/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8647e-05 - val_loss: 0.0014
# Epoch 324/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8410e-05 - val_loss: 0.0014
# Epoch 325/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0078e-05 - val_loss: 0.0014
# Epoch 326/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4922e-05 - val_loss: 0.0014
# Epoch 327/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1503e-05 - val_loss: 0.0014
# Epoch 328/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8672e-05 - val_loss: 0.0014
# Epoch 329/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7034e-05 - val_loss: 0.0013
# Epoch 330/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0322e-05 - val_loss: 0.0014
# Epoch 331/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0978e-05 - val_loss: 0.0014
# Epoch 332/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2132e-05 - val_loss: 0.0014
# Epoch 333/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2932e-05 - val_loss: 0.0013
# Epoch 334/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7591e-05 - val_loss: 0.0014
# Epoch 335/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.4798e-05 - val_loss: 0.0014
# Epoch 336/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1623e-05 - val_loss: 0.0014
# Epoch 337/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8082e-05 - val_loss: 0.0014
# Epoch 338/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0973e-05 - val_loss: 0.0014
# Epoch 339/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6247e-05 - val_loss: 0.0014
# Epoch 340/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0500e-05 - val_loss: 0.0014
# Epoch 341/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3225e-05 - val_loss: 0.0013
# Epoch 342/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4201e-05 - val_loss: 0.0014
# Epoch 343/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0608e-05 - val_loss: 0.0013
# Epoch 344/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.6826e-05 - val_loss: 0.0014
# Epoch 345/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2599e-05 - val_loss: 0.0013
# Epoch 346/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8590e-05 - val_loss: 0.0013
# Epoch 347/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0310e-05 - val_loss: 0.0013
# Epoch 348/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.0608e-05 - val_loss: 0.0014
# Epoch 349/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8276e-05 - val_loss: 0.0013
# Epoch 350/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7006e-05 - val_loss: 0.0014
# Epoch 351/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9081e-05 - val_loss: 0.0013
# Epoch 352/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.7409e-05 - val_loss: 0.0013
# Epoch 353/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4401e-05 - val_loss: 0.0013
# Epoch 354/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8639e-05 - val_loss: 0.0013
# Epoch 355/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2601e-05 - val_loss: 0.0013
# Epoch 356/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8853e-05 - val_loss: 0.0014
# Epoch 357/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9561e-05 - val_loss: 0.0013
# Epoch 358/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9497e-05 - val_loss: 0.0014
# Epoch 359/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1525e-05 - val_loss: 0.0013
# Epoch 360/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7274e-05 - val_loss: 0.0013
# Epoch 361/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.5207e-05 - val_loss: 0.0013
# Epoch 362/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9109e-05 - val_loss: 0.0013
# Epoch 363/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.1932e-05 - val_loss: 0.0013
# Epoch 364/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9273e-05 - val_loss: 0.0014
# Epoch 365/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3929e-05 - val_loss: 0.0013
# Epoch 366/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3826e-05 - val_loss: 0.0013
# Epoch 367/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1641e-05 - val_loss: 0.0013
# Epoch 368/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9793e-05 - val_loss: 0.0013
# Epoch 369/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8813e-05 - val_loss: 0.0013
# Epoch 370/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0192e-05 - val_loss: 0.0014
# Epoch 371/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7681e-05 - val_loss: 0.0013
# Epoch 372/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.6447e-05 - val_loss: 0.0013
# Epoch 373/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2532e-05 - val_loss: 0.0013
# Epoch 374/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9609e-05 - val_loss: 0.0013
# Epoch 375/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8354e-05 - val_loss: 0.0013
# Epoch 376/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9545e-05 - val_loss: 0.0013
# Epoch 377/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8140e-05 - val_loss: 0.0012
# Epoch 378/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6388e-05 - val_loss: 0.0013
# Epoch 379/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5360e-05 - val_loss: 0.0013
# Epoch 380/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2988e-05 - val_loss: 0.0013
# Epoch 381/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4597e-05 - val_loss: 0.0013
# Epoch 382/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1678e-05 - val_loss: 0.0013
# Epoch 383/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7344e-05 - val_loss: 0.0013
# Epoch 384/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9397e-05 - val_loss: 0.0013
# Epoch 385/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7117e-05 - val_loss: 0.0013
# Epoch 386/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.7588e-05 - val_loss: 0.0013
# Epoch 387/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8695e-05 - val_loss: 0.0013
# Epoch 388/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1471e-05 - val_loss: 0.0013
# Epoch 389/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5039e-05 - val_loss: 0.0013
# Epoch 390/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2481e-05 - val_loss: 0.0013
# Epoch 391/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4509e-05 - val_loss: 0.0013
# Epoch 392/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4919e-05 - val_loss: 0.0013
# Epoch 393/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1512e-05 - val_loss: 0.0013
# Epoch 394/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.5353e-05 - val_loss: 0.0013
# Epoch 395/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6846e-05 - val_loss: 0.0013
# Epoch 396/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8242e-05 - val_loss: 0.0013
# Epoch 397/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3274e-05 - val_loss: 0.0013
# Epoch 398/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2739e-05 - val_loss: 0.0013
# Epoch 399/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0526e-05 - val_loss: 0.0013
# Epoch 400/400
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9757e-05 - val_loss: 0.0013

# %%
import matplotlib.pyplot as plt

# Predicting
predicted_values = model.predict(X_test)
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='True Values')
plt.plot(predicted_values, label='Predicted Values')
plt.title('Comparison of Actual and Predicted Values')
plt.legend()
plt.show()
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
# Evaluate the model
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107
# Test Loss: 0.017785610631108284

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Lambda
import tensorflow.keras.backend as K

# Define the RNN model with bias correction included
model = Sequential([
    LSTM(50, activation='tanh', input_shape=(n_steps, n_features), return_sequences=True),
    Dropout(0.2),
    LSTM(50, activation='tanh'),
    Dropout(0.2),
    Dense(1),  # Output layer - initially outputs the raw predictions
    Lambda(lambda x: x + K.constant(0.5))  # Adding bias correction directly in the model
])

# Display model summary to verify its structure
model.summary()

# Compile the model using SGD optimizer
sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=sgd_optimizer, loss='mean_squared_error')

# Assuming X_train and y_train are already defined and properly shaped
history = model.fit(X_train, y_train, epochs=200, batch_size=32, verbose=1, validation_split=0.2)

# Predicting and plotting results
import matplotlib.pyplot as plt

predicted_values = model.predict(X_test)
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='True Values')
plt.plot(predicted_values, label='Predicted Values')
plt.title('Comparison of Actual and Predicted Values')
plt.legend()
plt.show()

# Evaluate the model
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
# Out:
# c:\Users\kzhan\Documents\GitHub\521-Final-Project\env\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:From c:\Users\kzhan\Documents\GitHub\521-Final-Project\env\Lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 50, 50)         │        12,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 50, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,251 (125.98 KB)
#  Trainable params: 32,251 (125.98 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0229 - val_loss: 0.0366
# Epoch 2/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1589e-04 - val_loss: 0.0362
# Epoch 3/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.6801e-04 - val_loss: 0.0363
# Epoch 4/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2422e-04 - val_loss: 0.0364
# Epoch 5/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.7647e-04 - val_loss: 0.0346
# Epoch 6/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.3687e-04 - val_loss: 0.0360
# Epoch 7/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2725e-04 - val_loss: 0.0358
# Epoch 8/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0239e-04 - val_loss: 0.0361
# Epoch 9/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6243e-04 - val_loss: 0.0350
# Epoch 10/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.6827e-04 - val_loss: 0.0361
# Epoch 11/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.8558e-04 - val_loss: 0.0346
# Epoch 12/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.3340e-04 - val_loss: 0.0350
# Epoch 13/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.5967e-04 - val_loss: 0.0343
# Epoch 14/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.6149e-04 - val_loss: 0.0344
# Epoch 15/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6694e-04 - val_loss: 0.0341
# Epoch 16/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.6562e-04 - val_loss: 0.0339
# Epoch 17/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2632e-04 - val_loss: 0.0338
# Epoch 18/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2920e-04 - val_loss: 0.0348
# Epoch 19/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1729e-04 - val_loss: 0.0328
# Epoch 20/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2371e-04 - val_loss: 0.0324
# Epoch 21/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2291e-04 - val_loss: 0.0324
# Epoch 22/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2864e-04 - val_loss: 0.0324
# Epoch 23/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8575e-04 - val_loss: 0.0322
# Epoch 24/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2946e-04 - val_loss: 0.0315
# Epoch 25/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9996e-04 - val_loss: 0.0318
# Epoch 26/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9647e-04 - val_loss: 0.0320
# Epoch 27/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8463e-04 - val_loss: 0.0301
# Epoch 28/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7824e-04 - val_loss: 0.0308
# Epoch 29/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1273e-04 - val_loss: 0.0307
# Epoch 30/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9663e-04 - val_loss: 0.0298
# Epoch 31/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8319e-04 - val_loss: 0.0295
# Epoch 32/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8862e-04 - val_loss: 0.0299
# Epoch 33/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7416e-04 - val_loss: 0.0289
# Epoch 34/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.6549e-04 - val_loss: 0.0289
# Epoch 35/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9029e-04 - val_loss: 0.0283
# Epoch 36/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7597e-04 - val_loss: 0.0287
# Epoch 37/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9094e-04 - val_loss: 0.0284
# Epoch 38/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7516e-04 - val_loss: 0.0276
# Epoch 39/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5411e-04 - val_loss: 0.0273
# Epoch 40/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7856e-04 - val_loss: 0.0270
# Epoch 41/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6476e-04 - val_loss: 0.0272
# Epoch 42/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.6597e-04 - val_loss: 0.0263
# Epoch 43/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3209e-04 - val_loss: 0.0268
# Epoch 44/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.2596e-04 - val_loss: 0.0262
# Epoch 45/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5523e-04 - val_loss: 0.0258
# Epoch 46/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2110e-04 - val_loss: 0.0258
# Epoch 47/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3335e-04 - val_loss: 0.0252
# Epoch 48/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0909e-04 - val_loss: 0.0250
# Epoch 49/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3759e-04 - val_loss: 0.0241
# Epoch 50/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0011e-04 - val_loss: 0.0245
# Epoch 51/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4330e-04 - val_loss: 0.0235
# Epoch 52/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4139e-04 - val_loss: 0.0229
# Epoch 53/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3193e-04 - val_loss: 0.0228
# Epoch 54/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0784e-04 - val_loss: 0.0233
# Epoch 55/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2151e-04 - val_loss: 0.0223
# Epoch 56/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0887e-04 - val_loss: 0.0226
# Epoch 57/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1716e-04 - val_loss: 0.0223
# Epoch 58/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1310e-04 - val_loss: 0.0217
# Epoch 59/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1631e-04 - val_loss: 0.0210
# Epoch 60/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3377e-04 - val_loss: 0.0207
# Epoch 61/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9660e-04 - val_loss: 0.0204
# Epoch 62/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9921e-04 - val_loss: 0.0202
# Epoch 63/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9943e-04 - val_loss: 0.0201
# Epoch 64/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1442e-04 - val_loss: 0.0197
# Epoch 65/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0601e-04 - val_loss: 0.0198
# Epoch 66/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8882e-04 - val_loss: 0.0191
# Epoch 67/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8834e-04 - val_loss: 0.0184
# Epoch 68/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0080e-04 - val_loss: 0.0185
# Epoch 69/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7618e-04 - val_loss: 0.0185
# Epoch 70/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8424e-04 - val_loss: 0.0176
# Epoch 71/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6394e-04 - val_loss: 0.0178
# Epoch 72/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6018e-04 - val_loss: 0.0177
# Epoch 73/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7136e-04 - val_loss: 0.0167
# Epoch 74/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7770e-04 - val_loss: 0.0165
# Epoch 75/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7572e-04 - val_loss: 0.0166
# Epoch 76/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6596e-04 - val_loss: 0.0167
# Epoch 77/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7526e-04 - val_loss: 0.0162
# Epoch 78/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7069e-04 - val_loss: 0.0155
# Epoch 79/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6660e-04 - val_loss: 0.0153
# Epoch 80/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8024e-04 - val_loss: 0.0151
# Epoch 81/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7393e-04 - val_loss: 0.0145
# Epoch 82/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5567e-04 - val_loss: 0.0144
# Epoch 83/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4482e-04 - val_loss: 0.0141
# Epoch 84/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5201e-04 - val_loss: 0.0134
# Epoch 85/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6866e-04 - val_loss: 0.0139
# Epoch 86/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4778e-04 - val_loss: 0.0131
# Epoch 87/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5215e-04 - val_loss: 0.0134
# Epoch 88/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6767e-04 - val_loss: 0.0130
# Epoch 89/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4184e-04 - val_loss: 0.0126
# Epoch 90/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3481e-04 - val_loss: 0.0123
# Epoch 91/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4566e-04 - val_loss: 0.0119
# Epoch 92/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5003e-04 - val_loss: 0.0120
# Epoch 93/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4668e-04 - val_loss: 0.0118
# Epoch 94/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3764e-04 - val_loss: 0.0115
# Epoch 95/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4430e-04 - val_loss: 0.0112
# Epoch 96/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2406e-04 - val_loss: 0.0110
# Epoch 97/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2495e-04 - val_loss: 0.0106
# Epoch 98/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3292e-04 - val_loss: 0.0103
# Epoch 99/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3214e-04 - val_loss: 0.0104
# Epoch 100/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3165e-04 - val_loss: 0.0099
# Epoch 101/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3625e-04 - val_loss: 0.0096
# Epoch 102/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2467e-04 - val_loss: 0.0099
# Epoch 103/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3508e-04 - val_loss: 0.0092
# Epoch 104/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0886e-04 - val_loss: 0.0089
# Epoch 105/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2258e-04 - val_loss: 0.0087
# Epoch 106/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1380e-04 - val_loss: 0.0086
# Epoch 107/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0444e-04 - val_loss: 0.0085
# Epoch 108/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2358e-04 - val_loss: 0.0084
# Epoch 109/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0918e-04 - val_loss: 0.0082
# Epoch 110/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1003e-04 - val_loss: 0.0081
# Epoch 111/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1967e-04 - val_loss: 0.0077
# Epoch 112/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0614e-04 - val_loss: 0.0078
# Epoch 113/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1643e-04 - val_loss: 0.0075
# Epoch 114/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0578e-04 - val_loss: 0.0073
# Epoch 115/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.5534e-05 - val_loss: 0.0072
# Epoch 116/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1457e-04 - val_loss: 0.0071
# Epoch 117/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0517e-04 - val_loss: 0.0069
# Epoch 118/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.9071e-05 - val_loss: 0.0067
# Epoch 119/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0558e-04 - val_loss: 0.0065
# Epoch 120/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0383e-04 - val_loss: 0.0062
# Epoch 121/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0035e-04 - val_loss: 0.0062
# Epoch 122/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0405e-04 - val_loss: 0.0059
# Epoch 123/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.4588e-05 - val_loss: 0.0062
# Epoch 124/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.5495e-05 - val_loss: 0.0058
# Epoch 125/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0259e-04 - val_loss: 0.0054
# Epoch 126/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.8155e-05 - val_loss: 0.0056
# Epoch 127/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0053e-04 - val_loss: 0.0054
# Epoch 128/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.0577e-05 - val_loss: 0.0052
# Epoch 129/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.7684e-05 - val_loss: 0.0051
# Epoch 130/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2769e-05 - val_loss: 0.0049
# Epoch 131/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.9181e-05 - val_loss: 0.0049
# Epoch 132/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.2782e-05 - val_loss: 0.0048
# Epoch 133/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0720e-04 - val_loss: 0.0047
# Epoch 134/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.8040e-05 - val_loss: 0.0047
# Epoch 135/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.4999e-05 - val_loss: 0.0044
# Epoch 136/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0423e-04 - val_loss: 0.0044
# Epoch 137/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7015e-05 - val_loss: 0.0043
# Epoch 138/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9912e-05 - val_loss: 0.0040
# Epoch 139/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.6966e-05 - val_loss: 0.0040
# Epoch 140/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.5709e-05 - val_loss: 0.0040
# Epoch 141/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6721e-05 - val_loss: 0.0041
# Epoch 142/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7607e-05 - val_loss: 0.0038
# Epoch 143/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.4903e-05 - val_loss: 0.0038
# Epoch 144/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.0592e-05 - val_loss: 0.0036
# Epoch 145/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2057e-05 - val_loss: 0.0037
# Epoch 146/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.1660e-05 - val_loss: 0.0034
# Epoch 147/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.1575e-05 - val_loss: 0.0034
# Epoch 148/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0817e-05 - val_loss: 0.0033
# Epoch 149/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.7892e-05 - val_loss: 0.0033
# Epoch 150/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8998e-05 - val_loss: 0.0033
# Epoch 151/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.5080e-05 - val_loss: 0.0032
# Epoch 152/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.4120e-05 - val_loss: 0.0032
# Epoch 153/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9116e-05 - val_loss: 0.0031
# Epoch 154/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.0692e-05 - val_loss: 0.0030
# Epoch 155/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3118e-05 - val_loss: 0.0029
# Epoch 156/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2760e-05 - val_loss: 0.0028
# Epoch 157/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1561e-05 - val_loss: 0.0029
# Epoch 158/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2359e-05 - val_loss: 0.0028
# Epoch 159/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9991e-05 - val_loss: 0.0026
# Epoch 160/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8671e-05 - val_loss: 0.0027
# Epoch 161/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4654e-05 - val_loss: 0.0028
# Epoch 162/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1618e-05 - val_loss: 0.0027
# Epoch 163/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8788e-05 - val_loss: 0.0025
# Epoch 164/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0961e-05 - val_loss: 0.0024
# Epoch 165/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3663e-05 - val_loss: 0.0025
# Epoch 166/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6568e-05 - val_loss: 0.0024
# Epoch 167/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2050e-05 - val_loss: 0.0023
# Epoch 168/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7752e-05 - val_loss: 0.0024
# Epoch 169/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7566e-05 - val_loss: 0.0023
# Epoch 170/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5906e-05 - val_loss: 0.0022
# Epoch 171/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3233e-05 - val_loss: 0.0022
# Epoch 172/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8331e-05 - val_loss: 0.0022
# Epoch 173/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8634e-05 - val_loss: 0.0022
# Epoch 174/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5851e-05 - val_loss: 0.0022
# Epoch 175/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5414e-05 - val_loss: 0.0021
# Epoch 176/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7160e-05 - val_loss: 0.0021
# Epoch 177/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4303e-05 - val_loss: 0.0020
# Epoch 178/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6556e-05 - val_loss: 0.0020
# Epoch 179/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0065e-05 - val_loss: 0.0019
# Epoch 180/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9477e-05 - val_loss: 0.0020
# Epoch 181/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2440e-05 - val_loss: 0.0020
# Epoch 182/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7405e-05 - val_loss: 0.0019
# Epoch 183/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4243e-05 - val_loss: 0.0020
# Epoch 184/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2347e-05 - val_loss: 0.0019
# Epoch 185/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2485e-05 - val_loss: 0.0019
# Epoch 186/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6578e-05 - val_loss: 0.0018
# Epoch 187/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4767e-05 - val_loss: 0.0019
# Epoch 188/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9438e-05 - val_loss: 0.0018
# Epoch 189/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8319e-05 - val_loss: 0.0018
# Epoch 190/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4369e-05 - val_loss: 0.0017
# Epoch 191/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.8065e-05 - val_loss: 0.0017
# Epoch 192/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.4711e-05 - val_loss: 0.0017
# Epoch 193/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0216e-05 - val_loss: 0.0017
# Epoch 194/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1854e-05 - val_loss: 0.0017
# Epoch 195/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.0010e-05 - val_loss: 0.0016
# Epoch 196/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.9399e-05 - val_loss: 0.0017
# Epoch 197/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.7622e-05 - val_loss: 0.0017
# Epoch 198/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2076e-05 - val_loss: 0.0016
# Epoch 199/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7272e-05 - val_loss: 0.0016
# Epoch 200/200
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.7365e-05 - val_loss: 0.0016
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.0120
# Test Loss: 0.0186415184289217

# %% [markdown]
# ## Model Specific Preprocessing

# %% [markdown]
# ## Model Specific Tuning

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ## Fitted Model and Results
#     - Report on hyper parameters
#     - Report on fit quality
#     - Ideas on improvement if the model was continued to be

# %% [markdown]
# ## RNN results (Franco)

# %% [markdown]
# # XGBoost (Hank)
# ## Why this model for this problem
# ## Model Architecture
# ## Model Specific Preprocessing
# ## Model Specific Tuning
# ## Model Evaluation

# %% [markdown]
# ## Fitted Model and Results
#     - Report on hyper parameters
#     - Report on fit quality
#     - Ideas on improvement if the model was continued to be

# %% [markdown]
# # Random Forest (Bhavesh)
# ## Why this model for this problem
# ## Model Architecture
# ## Model Specific Preprocessing
# ## Model Specific Tuning
# ## Model Evaluation

# %% [markdown]
# ## Fitted Model and Results
#     - Report on hyper parameters
#     - Report on fit quality
#     - Ideas on improvement if the model was continued to be
